# %%
import pandas as pd

# %%
df_forum = pd.read_csv("bda2019_dataset/forum2.csv",encoding="utf-8")
df_forum.head()
# Out:
#                   id p_type    s_name  s_area_name  comment_count  \
# 0  1451585357153_F01  forum  mobile01  投資與理財(生活娛樂)              1
# 1  1451616871574_F01  forum  mobile01  投資與理財(生活娛樂)              5
# 2  1451616872738_F01  forum  mobile01  投資與理財(生活娛樂)              4
# 3  1451618546867_F01  forum  mobile01  投資與理財(生活娛樂)              7
# 4  1451623256525_F01  forum  mobile01  投資與理財(生活娛樂)              7
#
#            post_time             title           author  \
# 0   2016/1/1 2:01:00                自刪        famas2200
# 1  2016/1/1 10:41:00   傳超微已打算將訂單下給格羅方德       taiwan2008
# 2  2016/1/1 10:45:00  蘋果將另尋成長動能發動購併 ??       taiwan2008
# 3  2016/1/1 11:19:00        [詢問] 停徵證所稅  Go Go Free Life
# 4  2016/1/1 12:29:00              網路出金        mobiliken
#
#                                              content  \
# 0                                   不小心發錯版主請幫忙刪除文章謝謝
# 1  台積電爭奪超微下一代繪圖處理器失利，因為傳超微已打算將訂單下給格羅方德（GlobalFoun...
# 2  有分析師認為 蘋果將另尋成長動能，或許會動用深到不行的口袋，發動購併，可能目標包括 Adob...
# 3  新聞相關報導:<BR>[立法院院會去年11月三讀修正通過所得稅法部分條文，刪除有關證所稅相關...
# 4                                請問一下，網路出金是什麼？謝謝各位喔。
#
#                                             page_url
# 0  http://www.mobile01.com/topicdetail.php?f=291&...
# 1  http://www.mobile01.com/topicdetail.php?f=291&...
# 2  http://www.mobile01.com/topicdetail.php?f=291&...
# 3  http://www.mobile01.com/topicdetail.php?f=291&...
# 4  http://www.mobile01.com/topicdetail.php?f=291&...

# %%
df_forum.to_json('bda2019_dataset/forum2.json', orient='records')

# %%
df_forum = pd.read_json("bda2019_dataset/forum2.json",encoding="utf-8")
df_forum.head()
# Out:
#             author  comment_count  \
# 0        famas2200              1
# 1       taiwan2008              5
# 2       taiwan2008              4
# 3  Go Go Free Life              7
# 4        mobiliken              7
#
#                                              content                 id  \
# 0                                   不小心發錯版主請幫忙刪除文章謝謝  1451585357153_F01
# 1  台積電爭奪超微下一代繪圖處理器失利，因為傳超微已打算將訂單下給格羅方德（GlobalFoun...  1451616871574_F01
# 2  有分析師認為 蘋果將另尋成長動能，或許會動用深到不行的口袋，發動購併，可能目標包括 Adob...  1451616872738_F01
# 3  新聞相關報導:<BR>[立法院院會去年11月三讀修正通過所得稅法部分條文，刪除有關證所稅相關...  1451618546867_F01
# 4                                請問一下，網路出金是什麼？謝謝各位喔。  1451623256525_F01
#
#   p_type                                           page_url  \
# 0  forum  http://www.mobile01.com/topicdetail.php?f=291&...
# 1  forum  http://www.mobile01.com/topicdetail.php?f=291&...
# 2  forum  http://www.mobile01.com/topicdetail.php?f=291&...
# 3  forum  http://www.mobile01.com/topicdetail.php?f=291&...
# 4  forum  http://www.mobile01.com/topicdetail.php?f=291&...
#
#             post_time  s_area_name    s_name             title
# 0 2016-01-01 02:01:00  投資與理財(生活娛樂)  mobile01                自刪
# 1 2016-01-01 10:41:00  投資與理財(生活娛樂)  mobile01   傳超微已打算將訂單下給格羅方德
# 2 2016-01-01 10:45:00  投資與理財(生活娛樂)  mobile01  蘋果將另尋成長動能發動購併 ??
# 3 2016-01-01 11:19:00  投資與理財(生活娛樂)  mobile01        [詢問] 停徵證所稅
# 4 2016-01-01 12:29:00  投資與理財(生活娛樂)  mobile01              網路出金
